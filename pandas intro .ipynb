# %%
import pandas as pd

# %% [markdown]
# # pandas' main 2 data-types
# DataFrame and Series

# %%
srs = pd.Series(['ho','bye','how','what'])
srs # series is only 1-D
# Out:
# 0      ho
# 1     bye
# 2     how
# 3    what
# dtype: object

# %%
df = pd.DataFrame({'expression':srs,'values':(1,2,3,4)})
df   # multi dimensional
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d01dc069b041> in <module>
# ----> 1 df = pd.DataFrame({'expression':srs,'values':(1,2,3,4)})
#       2 df   # multi dimensional
#
# NameError: name 'srs' is not defined

# %%
# reading data from external sources 
sale = pd.read_csv('original.csv')
sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # describing data
# data description

# %%
print(sale.columns)
sale.index
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')
# RangeIndex(start=0, stop=10, step=1)

# %%
sale.describe() # this is a function used to get the math of the whole df
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
sale.info()   # there is info()   and .info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %% [markdown]
#  ## stats
#  like mean mode median etc
#   general syntax
#  dataframe[column name or index or slicing if requied
#  ].method()

# %%
sale['Doors'].mean()   # gives the mean of numeric columns
# Out:
# 4.0

# %%
sale.var()   # the variance
# Out:
# Odometer (KM)    3.841951e+09
# Doors            2.222222e-01
# dtype: float64

# %%
sale.std() # this is the standard deviation
# Out:
# Odometer (KM)    61983.471735
# Doors                0.471405
# dtype: float64

# %%
sale.sum()   # return the sum of all columns
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %% [markdown]
# # viewing and selecting data

# %%
# top and bottom reading
print(sale.head(3),sale.tail(4))
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00      Make Colour  Odometer (KM)  Doors      Price
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc and .iloc
birds = pd.Series(['eagle','vulture','hornbill','sea-gull','sparrow'],
                  index = [2,4,5,6,2])
birds
# Out:
# 2       eagle
# 4     vulture
# 5    hornbill
# 6    sea-gull
# 2     sparrow
# dtype: object

# %% [markdown]
# # .loc function
# returnd the info of the rows accordingto the range
# general syntax
# frame.loc[ start :  stop  :  step  ]
# where the difference is accordimg tp imdex

# %%
birds.loc[2]    # .loc refers to the info of  specific range of cols and rowa
# Out:
# 2      eagle
# 2    sparrow
# dtype: object

# %%
sale.loc[2:4]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
sale.loc[2:4:2]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 2  Toyota   Blue          32549      3  $7,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %% [markdown]
# # iloc method
# this function returns the position of the argument or thr range
# index is not used here if its not in order

# %%
# iloc method refers to the row count wihtout the index or simply the position
sale.iloc[3:5]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
sale[(sale['Make'] == 'Toyota')]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %% [markdown]
# # pd.crosstab(column name ,  col_nmae )
# generally used to compare bw cols or list of cols

# %%
pd.crosstab(sale['Make'],[sale['Price'],sale['Doors']])
# Out:
# Price  $22,000.00 $3,500.00 $4,000.00 $4,500.00 $5,000.00 $6,250.00 $7,000.00  \
# Doors           5         4         4         4         4         4         3
# Make
# BMW             1         0         0         0         0         0         0
# Honda           0         0         0         0         1         0         0
# Nissan          0         1         0         0         0         0         0
# Toyota          0         0         1         1         0         1         1
#
# Price     $7,500.00 $9,700.00
# Doors   4         4         4
# Make
# BMW     0         0         0
# Honda   1         1         0
# Nissan  0         0         1
# Toyota  0         0         0

# %% [markdown]
# # .groupby()

# %%
sale.groupby(['Make']).describe()
# sale.groupby(['Make']).stat_functions()
# Out:
#        Odometer (KM)                                                   \
#                count           mean            std      min       25%
# Make
# BMW              1.0   11179.000000            NaN  11179.0  11179.00
# Honda            3.0   62778.333333   22219.728179  45698.0  50218.00
# Nissan           2.0  122347.500000  128336.345251  31600.0  76973.75
# Toyota           4.0   85451.250000   51015.991325  32549.0  53137.25
#
#                                       Doors                                  \
#              50%        75%       max count  mean  std  min   25%  50%  75%
# Make
# BMW      11179.0   11179.00   11179.0   1.0  5.00  NaN  5.0  5.00  5.0  5.0
# Honda    54738.0   71318.50   87899.0   3.0  4.00  0.0  4.0  4.00  4.0  4.0
# Nissan  122347.5  167721.25  213095.0   2.0  4.00  0.0  4.0  4.00  4.0  4.0
# Toyota   79606.5  111920.50  150043.0   4.0  3.75  0.5  3.0  3.75  4.0  4.0
#
#
#         max
# Make
# BMW     5.0
# Honda   4.0
# Nissan  4.0
# ...

# %% [markdown]
# # .plot() to make plots using pandas

# %%
sale['Odometer (KM)'].plot()

# %% [markdown]
# # histogram()

# %%
sale['Doors'].hist()

# %%
sale.Price = sale['Price']*100

# %%
sale['Price'].dtype
# Out:
# dtype('int32')

# %%
sale
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-dfb96ea01189> in <module>
# ----> 1 sale
#
# NameError: name 'sale' is not defined

# %% [markdown]
# # data manipulation

# %%
sale['Make'] = sale.Make.str.lower()     # can use any string function in idle

# %% [markdown]
# # fillna()  and dropna()
# a data frame may not contain complete data , so in that case , 'naN'  is shown in the place
# inorder to fill these places , use fillna()  and to drop it , use dropna()

# %%
# df.col = df[col].fillna(df[col].mean())    is the general syntax
sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# cols from series
seats = pd.Series([5,4,4,4,4])
sale['new col'] = seats

# %%
sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  new col
# 0  Toyota  White         150043      4   $4,000.00      5.0
# 1   Honda    Red          87899      4   $5,000.00      4.0
# 2  Toyota   Blue          32549      3   $7,000.00      4.0
# 3     BMW  Black          11179      5  $22,000.00      4.0
# 4  Nissan  White         213095      4   $3,500.00      4.0
# 5  Toyota  Green          99213      4   $4,500.00      NaN
# 6   Honda   Blue          45698      4   $7,500.00      NaN
# 7   Honda   Blue          54738      4   $7,000.00      NaN
# 8  Toyota  White          60000      4   $6,250.00      NaN
# 9  Nissan  White          31600      4   $9,700.00      NaN

# %%
sale.fillna(5,inplace = True)
sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  new col
# 0  Toyota  White         150043      4   $4,000.00      5.0
# 1   Honda    Red          87899      4   $5,000.00      4.0
# 2  Toyota   Blue          32549      3   $7,000.00      4.0
# 3     BMW  Black          11179      5  $22,000.00      4.0
# 4  Nissan  White         213095      4   $3,500.00      4.0
# 5  Toyota  Green          99213      4   $4,500.00      5.0
# 6   Honda   Blue          45698      4   $7,500.00      5.0
# 7   Honda   Blue          54738      4   $7,000.00      5.0
# 8  Toyota  White          60000      4   $6,250.00      5.0
# 9  Nissan  White          31600      4   $9,700.00      5.0

# %%
# column from a list 
fuel_consumption = [12,3,23,33,2,12,22,5,15,4]
sale['fuel_P_100KM'] = fuel_consumption
sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  new col  fuel_P_100KM
# 0  Toyota  White         150043      4   $4,000.00      5.0            12
# 1   Honda    Red          87899      4   $5,000.00      4.0             3
# 2  Toyota   Blue          32549      3   $7,000.00      4.0            23
# 3     BMW  Black          11179      5  $22,000.00      4.0            33
# 4  Nissan  White         213095      4   $3,500.00      4.0             2
# 5  Toyota  Green          99213      4   $4,500.00      5.0            12
# 6   Honda   Blue          45698      4   $7,500.00      5.0            22
# 7   Honda   Blue          54738      4   $7,000.00      5.0             5
# 8  Toyota  White          60000      4   $6,250.00      5.0            15
# 9  Nissan  White          31600      4   $9,700.00      5.0             4

# %%
# new column usung other cols in the df 
sale['lifetime_consumption'] = (sale['Odometer (KM)']/100)*sale['fuel_P_100KM']

# %%
sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  new col  fuel_P_100KM  \
# 0  Toyota  White         150043      4   $4,000.00      5.0            12
# 1   Honda    Red          87899      4   $5,000.00      4.0             3
# 2  Toyota   Blue          32549      3   $7,000.00      4.0            23
# 3     BMW  Black          11179      5  $22,000.00      4.0            33
# 4  Nissan  White         213095      4   $3,500.00      4.0             2
# 5  Toyota  Green          99213      4   $4,500.00      5.0            12
# 6   Honda   Blue          45698      4   $7,500.00      5.0            22
# 7   Honda   Blue          54738      4   $7,000.00      5.0             5
# 8  Toyota  White          60000      4   $6,250.00      5.0            15
# 9  Nissan  White          31600      4   $9,700.00      5.0             4
#
#    lifetime_consumption
# 0              18005.16
# 1               2636.97
# 2               7486.27
# 3               3689.07
# 4               4261.90
# ...

# %%
sale['fuel/100'] = sale.fuel_P_100KM
sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  new col  fuel_P_100KM  \
# 0  Toyota  White         150043      4   $4,000.00      5.0            12
# 1   Honda    Red          87899      4   $5,000.00      4.0             3
# 2  Toyota   Blue          32549      3   $7,000.00      4.0            23
# 3     BMW  Black          11179      5  $22,000.00      4.0            33
# 4  Nissan  White         213095      4   $3,500.00      4.0             2
# 5  Toyota  Green          99213      4   $4,500.00      5.0            12
# 6   Honda   Blue          45698      4   $7,500.00      5.0            22
# 7   Honda   Blue          54738      4   $7,000.00      5.0             5
# 8  Toyota  White          60000      4   $6,250.00      5.0            15
# 9  Nissan  White          31600      4   $9,700.00      5.0             4
#
#    lifetime_consumption  fuel/100
# 0              18005.16        12
# 1               2636.97         3
# 2               7486.27        23
# ...

# %%
sale.drop('fuel_P_100KM',axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  new col  \
# 0  Toyota  White         150043      4   $4,000.00      5.0
# 1   Honda    Red          87899      4   $5,000.00      4.0
# 2  Toyota   Blue          32549      3   $7,000.00      4.0
# 3     BMW  Black          11179      5  $22,000.00      4.0
# 4  Nissan  White         213095      4   $3,500.00      4.0
# 5  Toyota  Green          99213      4   $4,500.00      5.0
# 6   Honda   Blue          45698      4   $7,500.00      5.0
# 7   Honda   Blue          54738      4   $7,000.00      5.0
# 8  Toyota  White          60000      4   $6,250.00      5.0
# 9  Nissan  White          31600      4   $9,700.00      5.0
#
#    lifetime_consumption  fuel/100
# 0              18005.16        12
# 1               2636.97         3
# 2               7486.27        23
# 3               3689.07        33
# 4               4261.90         2
# 5              11905.56        12
# 6              10053.56        22
# ...

# %%
sale.lifetime_consumption.plot()

# %%
sale.lifetime_consumption.hist()

# %%
sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  new col  fuel_P_100KM  \
# 0  Toyota  White         150043      4   $4,000.00      5.0            12
# 1   Honda    Red          87899      4   $5,000.00      4.0             3
# 2  Toyota   Blue          32549      3   $7,000.00      4.0            23
# 3     BMW  Black          11179      5  $22,000.00      4.0            33
# 4  Nissan  White         213095      4   $3,500.00      4.0             2
# 5  Toyota  Green          99213      4   $4,500.00      5.0            12
# 6   Honda   Blue          45698      4   $7,500.00      5.0            22
# 7   Honda   Blue          54738      4   $7,000.00      5.0             5
# 8  Toyota  White          60000      4   $6,250.00      5.0            15
# 9  Nissan  White          31600      4   $9,700.00      5.0             4
#
#    lifetime_consumption  fuel/100
# 0              18005.16        12
# 1               2636.97         3
# 2               7486.27        23
# ...

# %%
sale.drop('Colour',axis=1,inplace=True)

# %%
sale
# Out:
#      Make  Odometer (KM)  Doors       Price  new col  fuel_P_100KM  \
# 0  Toyota         150043      4   $4,000.00      5.0            12
# 1   Honda          87899      4   $5,000.00      4.0             3
# 2  Toyota          32549      3   $7,000.00      4.0            23
# 3     BMW          11179      5  $22,000.00      4.0            33
# 4  Nissan         213095      4   $3,500.00      4.0             2
# 5  Toyota          99213      4   $4,500.00      5.0            12
# 6   Honda          45698      4   $7,500.00      5.0            22
# 7   Honda          54738      4   $7,000.00      5.0             5
# 8  Toyota          60000      4   $6,250.00      5.0            15
# 9  Nissan          31600      4   $9,700.00      5.0             4
#
#    lifetime_consumption  fuel/100
# 0              18005.16        12
# 1               2636.97         3
# 2               7486.27        23
# 3               3689.07        33
# 4               4261.90         2
# ...

# %% [markdown]
# # sample() method
# general syntax =  name.sample(fraction = int32)
# where fraction is the number in which the data is taken
# , . if frac ==1 , means 100%
#
#
# (  shiffle the indeces   )

# %%
sale.sample(frac = 1)
# Out:
#    level_0  index    Make  Odometer (KM)  Doors       Price  new col  \
# 5        5      5  Toyota          99213      4   $4,500.00      5.0
# 6        6      6   Honda          45698      4   $7,500.00      5.0
# 4        4      4  Nissan         213095      4   $3,500.00      4.0
# 8        8      8  Toyota          60000      4   $6,250.00      5.0
# 7        7      7   Honda          54738      4   $7,000.00      5.0
# 2        2      2  Toyota          32549      3   $7,000.00      4.0
# 0        0      0  Toyota         150043      4   $4,000.00      5.0
# 9        9      9  Nissan          31600      4   $9,700.00      5.0
# 3        3      3     BMW          11179      5  $22,000.00      4.0
# 1        1      1   Honda          87899      4   $5,000.00      4.0
#
#    fuel_P_100KM  lifetime_consumption  fuel/100
# 5            12              11905.56        12
# 6            22              10053.56        22
# 4             2               4261.90         2
# ...

# %%
# to  select  a random 20% of the data 
sale.sample(frac = 0.2)
# Out:
#    level_0  index    Make  Odometer (KM)  Doors      Price  new col  \
# 5        5      5  Toyota          99213      4  $4,500.00      5.0
# 2        2      2  Toyota          32549      3  $7,000.00      4.0
#
#    fuel_P_100KM  lifetime_consumption  fuel/100
# 5            12              11905.56        12
# 2            23               7486.27        23

# %%
# to reset the shuffled indeces use the method reset_index(inplace = )
sale.reset_index(drop = True ,inplace = True)

# %%
sale = sale.drop(['index','level_0'],axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-6e80589de79b> in <module>
# ----> 1 sale = sale.drop(['index','level_0'],axis = 1)
#       2 sale
#
# ~\Desktop\ml\env\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\Desktop\ml\env\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
sale
# Out:
#      Make  Odometer (KM)  Doors       Price  new col  fuel_P_100KM  \
# 0  Toyota         150043      4   $4,000.00      5.0            12
# 1   Honda          87899      4   $5,000.00      4.0             3
# 2  Toyota          32549      3   $7,000.00      4.0            23
# 3     BMW          11179      5  $22,000.00      4.0            33
# 4  Nissan         213095      4   $3,500.00      4.0             2
# 5  Toyota          99213      4   $4,500.00      5.0            12
# 6   Honda          45698      4   $7,500.00      5.0            22
# 7   Honda          54738      4   $7,000.00      5.0             5
# 8  Toyota          60000      4   $6,250.00      5.0            15
# 9  Nissan          31600      4   $9,700.00      5.0             4
#
#    lifetime_consumption  fuel/100
# 0              18005.16        12
# 1               2636.97         3
# 2               7486.27        23
# 3               3689.07        33
# 4               4261.90         2
# ...

# %%
sale.drop('fuel_P_100KM',axis=1,inplace=True)

# %%
sale
# Out:
#      Make  Odometer (KM)  Doors       Price  new col  lifetime_consumption  \
# 0  Toyota         150043      4   $4,000.00      5.0              18005.16
# 1   Honda          87899      4   $5,000.00      4.0               2636.97
# 2  Toyota          32549      3   $7,000.00      4.0               7486.27
# 3     BMW          11179      5  $22,000.00      4.0               3689.07
# 4  Nissan         213095      4   $3,500.00      4.0               4261.90
# 5  Toyota          99213      4   $4,500.00      5.0              11905.56
# 6   Honda          45698      4   $7,500.00      5.0              10053.56
# 7   Honda          54738      4   $7,000.00      5.0               2736.90
# 8  Toyota          60000      4   $6,250.00      5.0               9000.00
# 9  Nissan          31600      4   $9,700.00      5.0               1264.00
#
#    fuel/100
# 0        12
# 1         3
# 2        23
# 3        33
# 4         2
# 5        12
# 6        22
# 7         5
# 8        15
# ...

# %% [markdown]
# # renaming a col is done using the function rename
#
# synatx = df.rename(columns = {'col1':'new1',col2:'new2'})

# %%
sale.rename(columns = {'Odometer ()'})
